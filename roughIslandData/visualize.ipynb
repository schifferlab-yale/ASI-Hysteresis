# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.load("r1;p0.5;a5.12e-07;l3.0000000000000004e-07;s2.out/m000000.npy")
data=data[0,1,:,:]

data = data==0 * data

data=data[220:290,50:210]


plt.imshow(data, cmap="gray")
